# %% [markdown]
# # Hyperameter tuning (of additional layer(s) added during transfer learning, with experimental training set) using Keras tuner
# ### target is validation loss, best model is saved, tunable parameters are number of hidden layers, number of units in each layer, batch size,

# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import math
from LSTMutils import MeanVarianceLogLikelyhoodLoss
from LSTMutils import LSTMnetwork
from sklearn.model_selection import train_test_split
import keras_tuner as kt

np.random.seed(42)
tf.random.set_seed(42) 

SequenceLength = 250
validation_split = 0.25
# batch_size = 32
NumEpochs = 2000
test_split = 0.2

reconstructed_model = keras.models.load_model("../Models/SimulatedDataPretrainedModel",custom_objects={"MeanVarianceLogLikelyhoodLoss": MeanVarianceLogLikelyhoodLoss})

reconstructed_model.trainable = False

# read experimental data and split into time (s) converted to hours, concentration labels and time series data
df_full = pd.read_csv(r"../TrainingData/ExperimentalTrainingSet.csv",sep=',',header=None)
time = df_full.iloc[0,1:]/3600
labels = df_full.iloc[1:,0]
df_data = df_full.iloc[1:,1:]

df = pd.read_csv(r"../TrainingData/SimulatedTrainingSet10000.csv",sep=',',header=0)
df_simulated = df.iloc[:,1:]

# split data into stratified train and test sets, size defined by the test_split variable
# the split will always be the same provided the data is in the same order, the same random_state is used,
# and strangely the labels used for stratification are always the same type (str)

df_train, df_test = train_test_split(df_data, test_size=test_split, train_size=1-test_split, random_state=42, shuffle=True, stratify=labels)

train_labels = df_train.iloc[:,0]

df_train, df_val = train_test_split(df_train, test_size=validation_split, train_size=1-validation_split, random_state=42, shuffle=True, stratify=train_labels)

# normalise time series data
min_value, max_value = df_train.min().min(), df_train.max().max()
df_norm_train = (df_train - min_value)/(max_value - min_value)
df_norm_test = (df_test - min_value)/(max_value - min_value)
df_norm_val = (df_val - min_value)/(max_value - min_value)
    
X_train = df_norm_train.iloc[:,:SequenceLength].values
y_train = df_norm_train.iloc[:,SequenceLength-1].values
X_train = np.expand_dims(X_train, 2)
y_train = np.broadcast_to(y_train[:,None], (y_train.shape[0],SequenceLength))
y_train = np.expand_dims(y_train, 2)

X_val = df_norm_val.iloc[:,:SequenceLength].values
y_val = df_norm_val.iloc[:,SequenceLength-1].values
X_val = np.expand_dims(X_val, 2)
y_val = np.broadcast_to(y_val[:,None], (y_val.shape[0],SequenceLength))
y_val = np.expand_dims(y_val, 2)


#Implementation informed by https://github.com/keras-team/keras-tuner/issues/122

class LSTMHyperModel(kt.HyperModel):
    
    def build(self,hp):
        model = keras.models.Sequential([reconstructed_model
                        , keras.layers.LSTM(hp.Choice("layer_1_units", [2,5,10,20,50,100,200,500]), return_sequences=True)])#, kernel_regularizer=keras.regularizers.L2(hp.Choice("L2Regularizer1", [0., 1e-4]))))
#         if hp.Boolean("layer_1_dropout"):
#             model.add(keras.layers.Dropout(rate=0.25))
        for i in range(hp.Int("LSTM Layers", min_value = 0, max_value = 8)):
             model.add(keras.layers.LSTM(hp.Choice(f"layer_{i+2}_units", [2,5,10,20,50,100,200,500]), return_sequences=True))#, kernel_regularizer=keras.regularizers.L2(hp.Choice(f"L2Regularizer{i+2}", [0., 1e-4]))))
# #             if hp.Boolean(f"layer_{i+2}_Dropout"):
# #                 model.add(keras.layers.Dropout(rate=0.25))
        #learning_rate = hp.Float("lr", min_value=1e-5, max_value=1e-2, sampling="log")
        model.add(keras.layers.LSTM(2, activation='softplus',return_sequences=True))

        model.compile(optimizer="adam",loss = MeanVarianceLogLikelyhoodLoss)
    
        return model

    
    def fit(self, hp, model, *args, **kwargs):
        return model.fit(*args,batch_size=hp.Choice("batch_size",[16,32,64,128,254]),**kwargs)
    
tuner = kt.RandomSearch(#kt.BayesianOptimization(#kt.Hyperband(#
    LSTMHyperModel(),
    objective='val_loss',
    overwrite = True,#False,#
    #beta=5,
    #factor = 3,
    #hyperband_iterations = 1,
    #max_epochs = 100,
    max_trials = 300,
    seed = 42,
    directory = "../Models/ExperimentalDataTransferLearningModelTuner")
        
tuner.search(X_train, y_train, epochs=NumEpochs, validation_data=(X_val,y_val), callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss',patience=100)])
best_model = tuner.get_best_models()[0]
best_model.summary()
best_model.save("../Models/ExperimentalDataTransferLearningModelTuner")
# Out:
# Trial 69 Complete [00h 00m 43s]
# val_loss: nan
#
# Best val_loss So Far: -3.4095356464385986
# Total elapsed time: 15h 24m 56s
#
# Search: Running Trial #70
#
# Value             |Best Value So Far |Hyperparameter
# 10                |5                 |layer_1_units
# 2                 |0                 |LSTM Layers
# 64                |16                |batch_size
# 2                 |None              |layer_2_units
# 10                |None              |layer_3_units
# 2                 |None              |layer_4_units
# 50                |None              |layer_5_units
# 5                 |None              |layer_6_units
# 5                 |None              |layer_7_units
# 2                 |None              |layer_8_units
# 200               |None              |layer_9_units
#
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/2000
# 4/4 [==============================] - 7s 706ms/step - loss: 10.3235 - val_loss: 9.9169
# Epoch 2/2000
# 4/4 [==============================] - 1s 271ms/step - loss: 9.6629 - val_loss: 9.1488
# Epoch 3/2000
# 4/4 [==============================] - 1s 278ms/step - loss: 8.8151 - val_loss: 8.1140
# Epoch 4/2000
# 4/4 [==============================] - 1s 299ms/step - loss: 7.6205 - val_loss: 6.5558
# Epoch 5/2000
# 4/4 [==============================] - 1s 272ms/step - loss: 5.7150 - val_loss: 3.5600
# Epoch 6/2000
# 4/4 [==============================] - 1s 278ms/step - loss: 204.4195 - val_loss: 633.0394
# Epoch 7/2000
# 4/4 [==============================] - 1s 266ms/step - loss: 545.9420 - val_loss: 802.4597
# Epoch 8/2000
# 4/4 [==============================] - 1s 264ms/step - loss: 583.6462 - val_loss: 973.6082
# Epoch 9/2000
# 4/4 [==============================] - 1s 255ms/step - loss: 706.9784 - val_loss: 845.0548
# Epoch 10/2000
# 4/4 [==============================] - 1s 279ms/step - loss: 554.6252 - val_loss: 168.5088
# Epoch 11/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 82.9464 - val_loss: 35.7727
# Epoch 12/2000
# 4/4 [==============================] - 1s 278ms/step - loss: 20.8450 - val_loss: 0.4651
# Epoch 13/2000
# 4/4 [==============================] - 1s 263ms/step - loss: 0.3776 - val_loss: 0.2623
# Epoch 14/2000
# 4/4 [==============================] - 1s 272ms/step - loss: 0.2290 - val_loss: 0.2005
# Epoch 15/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1827 - val_loss: 0.1753
# Epoch 16/2000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.1605 - val_loss: 0.1604
# Epoch 17/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1475 - val_loss: 0.1506
# Epoch 18/2000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1391 - val_loss: 0.1445
# Epoch 19/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1339 - val_loss: 0.1402
# Epoch 20/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1301 - val_loss: 0.1376
# Epoch 21/2000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1278 - val_loss: 0.1356
# Epoch 22/2000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1261 - val_loss: 0.1343
# Epoch 23/2000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1250 - val_loss: 0.1336
# Epoch 24/2000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.1244 - val_loss: 0.1331
# Epoch 25/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1240 - val_loss: 0.1328
# Epoch 26/2000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1236 - val_loss: 0.1324
# Epoch 27/2000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1234 - val_loss: 0.1323
# Epoch 28/2000
# 4/4 [==============================] - 1s 268ms/step - loss: 0.1233 - val_loss: 0.1321
# Epoch 29/2000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1231 - val_loss: 0.1321
# Epoch 30/2000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1230 - val_loss: 0.1320
# Epoch 31/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1230 - val_loss: 0.1320
# Epoch 32/2000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1229 - val_loss: 0.1320
# Epoch 33/2000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1229 - val_loss: 0.1320
# Epoch 34/2000
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 35/2000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 36/2000
# 4/4 [==============================] - 1s 266ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 37/2000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 38/2000
# 4/4 [==============================] - 1s 268ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 39/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 40/2000
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 41/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 42/2000
# 4/4 [==============================] - 1s 271ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 43/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 44/2000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 45/2000
# 4/4 [==============================] - 1s 268ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 46/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 47/2000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 48/2000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 49/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 50/2000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 51/2000
# 4/4 [==============================] - 1s 271ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 52/2000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 53/2000
# 4/4 [==============================] - 1s 271ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 54/2000
# 4/4 [==============================] - 1s 268ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 55/2000
# 4/4 [==============================] - 1s 268ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 56/2000
# 4/4 [==============================] - 1s 272ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 57/2000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 58/2000
# 4/4 [==============================] - 1s 262ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 59/2000
# 4/4 [==============================] - 1s 268ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 60/2000
# 4/4 [==============================] - 1s 272ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 61/2000
# 4/4 [==============================] - 1s 270ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 62/2000
# 4/4 [==============================] - 1s 265ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 63/2000
# 4/4 [==============================] - 1s 257ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 64/2000
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 65/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 66/2000
# 4/4 [==============================] - 1s 271ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 67/2000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 68/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 69/2000
# 4/4 [==============================] - 1s 265ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 70/2000
# 4/4 [==============================] - 1s 268ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 71/2000
# 4/4 [==============================] - 1s 266ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 72/2000
# 4/4 [==============================] - 1s 263ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 73/2000
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 74/2000
# 4/4 [==============================] - 1s 272ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 75/2000
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 76/2000
# 4/4 [==============================] - 1s 269ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 77/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 78/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 79/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 80/2000
# 4/4 [==============================] - 1s 260ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 81/2000
# 4/4 [==============================] - 1s 267ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 82/2000
# 4/4 [==============================] - 1s 267ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 83/2000
# 4/4 [==============================] - 1s 272ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 84/2000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 85/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 86/2000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 87/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 88/2000
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 89/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 90/2000
# 4/4 [==============================] - 1s 269ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 91/2000
# 4/4 [==============================] - 1s 269ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 92/2000
# 4/4 [==============================] - 1s 269ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 93/2000
# 4/4 [==============================] - 1s 267ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 94/2000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 95/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 96/2000
# 4/4 [==============================] - 1s 261ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 97/2000
# 4/4 [==============================] - 1s 272ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 98/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 99/2000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 100/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 101/2000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 102/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 103/2000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 104/2000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 105/2000
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 106/2000
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 107/2000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 108/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 109/2000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 110/2000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 111/2000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 112/2000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 113/2000
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 114/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 115/2000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 116/2000
# 4/4 [==============================] - 1s 268ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 117/2000
# 4/4 [==============================] - 1s 264ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 118/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 119/2000
# 4/4 [==============================] - 1s 269ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 120/2000
# 4/4 [==============================] - 1s 266ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 121/2000
# 4/4 [==============================] - 1s 258ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 122/2000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 123/2000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 124/2000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 125/2000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 126/2000
# 4/4 [==============================] - 1s 270ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 127/2000
# 4/4 [==============================] - 1s 270ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 128/2000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 129/2000
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 130/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 131/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 132/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 133/2000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 134/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 135/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 136/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 137/2000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 138/2000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 139/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 140/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 141/2000
# 4/4 [==============================] - 1s 270ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 142/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 143/2000
# 4/4 [==============================] - 1s 259ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 144/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 145/2000
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 146/2000
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 147/2000
# 4/4 [==============================] - 1s 266ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 148/2000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 149/2000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 150/2000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 151/2000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 152/2000
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 153/2000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 154/2000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 155/2000
# 4/4 [==============================] - 1s 424ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 156/2000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 157/2000
# 4/4 [==============================] - 1s 266ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 158/2000
# 4/4 [==============================] - 1s 265ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 159/2000
# 4/4 [==============================] - 1s 269ms/step - loss: 0.1229 - val_loss: 0.1319
# Epoch 160/2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1292991/3728528106.py in <module>
#      86     directory = "../Models/ExperimentalDataTransferLearningModelTuner")
#      87
# ---> 88 tuner.search(X_train, y_train, epochs=NumEpochs, validation_split=validation_split, callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss',patience=100)])
#      89 best_model = tuner.get_best_models()[0]
#      90 best_model.summary()
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/keras_tuner/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     181
#     182             self.on_trial_begin(trial)
# --> 183             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     184             # `results` is None indicates user updated oracle in `run_trial()`.
#     185             if results is None:
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/keras_tuner/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     293             callbacks.append(model_checkpoint)
#     294             copied_kwargs["callbacks"] = callbacks
# --> 295             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     296
#     297             histories.append(obj_value)
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/keras_tuner/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     220         hp = trial.hyperparameters
#     221         model = self._try_build(hp)
# --> 222         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     223         tuner_utils.validate_trial_results(
#     224             results, self.oracle.objective, "HyperModel.fit()"
#
# /tmp/ipykernel_1292991/3728528106.py in fit(self, hp, model, *args, **kwargs)
#      72
#      73     def fit(self, hp, model, *args, **kwargs):
# ---> 74         return model.fit(*args,batch_size=hp.Choice("batch_size",[16,32,64,128,254]),**kwargs)
#      75
#      76 tuner = kt.RandomSearch(#kt.BayesianOptimization(#kt.Hyperband(#
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
tuner.results_summary(20)
# Out:
# Results summary
# Results in ../Models/ExperimentalDataTransferLearningModelTuner/untitled_project
# Showing 20 best trials
# <keras_tuner.engine.objective.Objective object at 0x7f34dcb57820>
# Trial summary
# Hyperparameters:
# layer_1_units: 5
# LSTM Layers: 0
# batch_size: 32
# Score: -3.4169135093688965
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 500
# layer_4_units: 500
# layer_5_units: 2
# layer_6_units: 5
# layer_7_units: 2
# layer_8_units: 500
# layer_9_units: 500
# Score: -3.3951098918914795
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 2
# layer_4_units: 500
# layer_5_units: 500
# layer_6_units: 2
# layer_7_units: 2
# layer_8_units: 500
# layer_9_units: 500
# Score: -3.357745885848999
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 500
# Score: -3.3499293327331543
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 2
# layer_4_units: 2
# layer_5_units: 500
# layer_6_units: 2
# layer_7_units: 2
# layer_8_units: 500
# layer_9_units: 2
# Score: -3.3358302116394043
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 50
# layer_4_units: 2
# layer_5_units: 500
# layer_6_units: 500
# layer_7_units: 2
# layer_8_units: 500
# layer_9_units: 500
# Score: -3.3222296237945557
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 500
# layer_4_units: 500
# layer_5_units: 500
# layer_6_units: 2
# layer_7_units: 2
# layer_8_units: 500
# layer_9_units: 2
# Score: -3.319411039352417
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 100
# layer_4_units: 2
# layer_5_units: 500
# layer_6_units: 2
# layer_7_units: 500
# layer_8_units: 500
# layer_9_units: 500
# Score: -3.3072962760925293
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 2
# layer_4_units: 500
# layer_5_units: 500
# layer_6_units: 500
# layer_7_units: 500
# layer_8_units: 500
# layer_9_units: 500
# Score: -3.300877809524536
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 2
# layer_4_units: 2
# layer_5_units: 2
# layer_6_units: 2
# layer_7_units: 2
# layer_8_units: 500
# layer_9_units: 500
# Score: -3.2669246196746826
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 500
# layer_4_units: 500
# layer_5_units: 500
# layer_6_units: 2
# layer_7_units: 500
# layer_8_units: 2
# layer_9_units: 500
# Score: -3.2538435459136963
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 500
# layer_4_units: 2
# layer_5_units: 2
# layer_6_units: 500
# layer_7_units: 500
# layer_8_units: 500
# layer_9_units: 500
# Score: -3.2463791370391846
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 2
# layer_4_units: 2
# layer_5_units: 2
# layer_6_units: 500
# layer_7_units: 2
# layer_8_units: 500
# layer_9_units: 2
# Score: -3.244633436203003
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 500
# layer_4_units: 20
# layer_5_units: 500
# layer_6_units: 2
# layer_7_units: 2
# layer_8_units: 500
# layer_9_units: 500
# Score: -3.2208988666534424
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 500
# layer_4_units: 20
# layer_5_units: 500
# layer_6_units: 500
# layer_7_units: 500
# layer_8_units: 500
# layer_9_units: 2
# Score: -3.219493865966797
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 32
# layer_2_units: 2
# layer_3_units: 2
# layer_4_units: 500
# layer_5_units: 2
# layer_6_units: 100
# layer_7_units: 2
# layer_8_units: 2
# layer_9_units: 2
# Score: -3.1895811557769775
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 128
# layer_2_units: 2
# layer_3_units: 5
# layer_4_units: 2
# layer_5_units: 500
# layer_6_units: 50
# layer_7_units: 2
# layer_8_units: 2
# layer_9_units: 2
# Score: -3.1455376148223877
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 64
# layer_2_units: 2
# layer_3_units: 5
# layer_4_units: 2
# layer_5_units: 2
# layer_6_units: 100
# layer_7_units: 2
# layer_8_units: 2
# layer_9_units: 500
# Score: -3.1306567192077637
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 128
# layer_2_units: 2
# layer_3_units: 5
# layer_4_units: 20
# layer_5_units: 2
# layer_6_units: 5
# layer_7_units: 100
# layer_8_units: 100
# layer_9_units: 10
# Score: -3.09812068939209
# Trial summary
# Hyperparameters:
# layer_1_units: 2
# LSTM Layers: 0
# batch_size: 254
# layer_2_units: 2
# layer_3_units: 2
# layer_4_units: 2
# layer_5_units: 2
# layer_6_units: 500
# layer_7_units: 2
# layer_8_units: 2
# layer_9_units: 2
# Score: -3.0902316570281982
